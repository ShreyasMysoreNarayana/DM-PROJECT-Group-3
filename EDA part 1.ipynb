# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_movie = pd.read_csv('movie.csv')
data_movie
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
data_rating = pd.read_csv('rating.csv')
data_rating
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
data_rating.drop('timestamp', axis = 1, inplace=True)

# %%
df = pd.merge(data_movie, data_rating, on = 'movieId')

# %%
df.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# userId     0
# rating     0
# dtype: int64

# %%
merged_data=df.copy()
merged_data
# Out:
#           movieId                          title  \
# 0               1               Toy Story (1995)
# 1               1               Toy Story (1995)
# 2               1               Toy Story (1995)
# 3               1               Toy Story (1995)
# 4               1               Toy Story (1995)
# ...           ...                            ...
# 20000258   131254   Kein Bund für's Leben (2007)
# 20000259   131256  Feuer, Eis & Dosenbier (2002)
# 20000260   131258             The Pirates (2014)
# 20000261   131260            Rentun Ruusu (2001)
# 20000262   131262               Innocence (2014)
#
#                                                genres  userId  rating
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2         Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3         Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# ...

# %%
merged_data.movieId.value_counts()
# Out:
# 296       67310
# 356       66172
# 318       63366
# 593       63299
# 480       59715
#           ...
# 110807        1
# 110811        1
# 78984         1
# 110818        1
# 131262        1
# Name: movieId, Length: 26744, dtype: int64

# %%
merged_data.movieId.value_counts()[merged_data.movieId.value_counts()>20]
# Out:
# 296       67310
# 356       66172
# 318       63366
# 593       63299
# 480       59715
#           ...
# 105248       21
# 71178        21
# 80374        21
# 26689        21
# 57964        21
# Name: movieId, Length: 12989, dtype: int64

# %%
merged_data.to_csv('/Users/azharmadanisyed/Desktop/archive/final_dataset.csv', index = False)

# %%
merged_data
# Out:
#           movieId                          title  \
# 0               1               Toy Story (1995)
# 1               1               Toy Story (1995)
# 2               1               Toy Story (1995)
# 3               1               Toy Story (1995)
# 4               1               Toy Story (1995)
# ...           ...                            ...
# 20000258   131254   Kein Bund für's Leben (2007)
# 20000259   131256  Feuer, Eis & Dosenbier (2002)
# 20000260   131258             The Pirates (2014)
# 20000261   131260            Rentun Ruusu (2001)
# 20000262   131262               Innocence (2014)
#
#                                                genres  userId  rating
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2         Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3         Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# ...

# %%
df
# Out:
#           movieId                          title  \
# 0               1               Toy Story (1995)
# 1               1               Toy Story (1995)
# 2               1               Toy Story (1995)
# 3               1               Toy Story (1995)
# 4               1               Toy Story (1995)
# ...           ...                            ...
# 20000258   131254   Kein Bund für's Leben (2007)
# 20000259   131256  Feuer, Eis & Dosenbier (2002)
# 20000260   131258             The Pirates (2014)
# 20000261   131260            Rentun Ruusu (2001)
# 20000262   131262               Innocence (2014)
#
#                                                genres  userId  rating
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2         Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3         Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# ...

# %%
# Basic Statistics
basic_stats = {
    "missing_values": df.isnull().sum(),
    "duplicates": df.duplicated().sum(),
    "unique_counts": df.nunique()
}
print("Basic Statistics:")
print(pd.DataFrame(basic_stats))
# Out:
# Basic Statistics:
#          missing_values  duplicates  unique_counts
# movieId               0           0          26744
# title                 0           0          26729
# genres                0           0           1329
# userId                0           0         138493
# rating                0           0             10

# %%
# User Behavior - distribution of ratings by userId
user_rating_counts = df['userId'].value_counts()
print("\nUser Rating Counts:")
print(user_rating_counts)
# Out:
# User Rating Counts:
# 118205    9254
# 8405      7515
# 82418     5646
# 121535    5520
# 125794    5491
#           ...
# 44694       20
# 29382       20
# 40667       20
# 96357       20
# 5249        20
# Name: userId, Length: 138493, dtype: int64

# %%
# Movie Popularity - count ratings per movieId
movie_rating_counts = df['movieId'].value_counts()
print("\nMovie Rating Counts:")
print(movie_rating_counts)
# Out:
# Movie Rating Counts:
# 296       67310
# 356       66172
# 318       63366
# 593       63299
# 480       59715
#           ...
# 110807        1
# 110811        1
# 78984         1
# 110818        1
# 131262        1
# Name: movieId, Length: 26744, dtype: int64

# %%
# Genre Analysis - split genres and count each genre
genre_counts = df['genres'].str.split('|').explode().value_counts()
print("\nGenre Counts:")
print(genre_counts)
# Out:
# Genre Counts:
# Drama                 8857853
# Comedy                7502234
# Action                5614208
# Thriller              5313506
# Adventure             4380351
# Romance               3802002
# Crime                 3298335
# Sci-Fi                3150141
# Fantasy               2111403
# Children              1669249
# Mystery               1557282
# Horror                1482737
# Animation             1140476
# War                   1048618
# Musical                870915
# IMAX                   492366
# Western                423714
# Documentary            244619
# Film-Noir              216689
# (no genres listed)        361
# Name: genres, dtype: int64

# %%
# Rating Distribution - examine the distribution of ratings
rating_distribution = df['rating'].value_counts()
print("\nRating Distribution:")
print(rating_distribution)
# Out:
# Rating Distribution:
# 4.0    5561926
# 3.0    4291193
# 5.0    2898660
# 3.5    2200156
# 4.5    1534824
# 2.0    1430997
# 2.5     883398
# 1.0     680732
# 1.5     279252
# 0.5     239125
# Name: rating, dtype: int64

# %%
# User Behavior - distribution of ratings by userId
user_rating_counts = df['userId'].value_counts()

# Movie Popularity - count ratings per movieId
movie_rating_counts = df['movieId'].value_counts()

# Genre Analysis - split genres and count each genre
genre_counts = df['genres'].str.split('|').explode().value_counts()

# Rating Distribution - examine the distribution of ratings
rating_distribution = df['rating'].value_counts()

# Plotting genre counts and rating distribution in two separate plots
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle("Exploratory Data Analysis Visualizations")

# Genre Analysis - Genre popularity
axs[0].bar(genre_counts.index, genre_counts.values, color='lightgreen')
axs[0].set_title('Genre Counts')
axs[0].set_xlabel('Genre')
axs[0].set_ylabel('Frequency')
axs[0].tick_params(axis='x', rotation=45)

# Rating Distribution - Distribution of ratings
axs[1].bar(rating_distribution.index, rating_distribution.values, color='lightcoral')
axs[1].set_title('Rating Distribution')
axs[1].set_xlabel('Rating')
axs[1].set_ylabel('Frequency')

# Adjust layout and display
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Box Plot: Ratings by Genre
plt.figure(figsize=(12, 8))
df_exploded = df.assign(genres=df['genres'].str.split('|')).explode('genres')
sns.boxplot(data=df_exploded, x='genres', y='rating')
plt.title('Box Plot of Ratings by Genre')
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()

# %%
df_exploded[df_exploded.genres == 'Adventure']['rating'].min()
# Out:
# 0.5

# %%
# Group by movieId to see average rating and rating count per movie
movie_group = df.groupby('movieId').agg({'rating': ['mean', 'count']}).reset_index()
print("Average Rating and Rating Count per Movie:\n", movie_group)
# Out:
# Average Rating and Rating Count per Movie:
#        movieId    rating
#                    mean  count
# 0           1  3.921240  49695
# 1           2  3.211977  22243
# 2           3  3.151040  12735
# 3           4  2.861393   2756
# 4           5  3.064592  12161
# ...       ...       ...    ...
# 26739  131254  4.000000      1
# 26740  131256  4.000000      1
# 26741  131258  2.500000      1
# 26742  131260  3.000000      1
# 26743  131262  4.000000      1
#
# [26744 rows x 3 columns]

# %% [markdown]
# ## 1. Top Movies by Average Rating and Popularity

# %%
# Top movies by average rating (considering movies with at least 5 ratings for reliability)
top_rated_movies = df.groupby('title').filter(lambda x: x['rating'].count() >= 5)
top_rated_movies = top_rated_movies.groupby('title')['rating'].mean().sort_values(ascending=False).head(10)

# Top movies by number of ratings
most_rated_movies = df['title'].value_counts().head(10)

# Plot top-rated movies
plt.figure(figsize=(10, 6))
top_rated_movies.plot(kind='bar', color='lightblue')
plt.title('Top 10 Movies by Average Rating')
plt.xlabel('Movie Title')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# Plot most-rated movies
plt.figure(figsize=(10, 6))
most_rated_movies.plot(kind='bar', color='salmon')
plt.title('Top 10 Movies by Number of Ratings')
plt.xlabel('Movie Title')
plt.ylabel('Number of Ratings')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 2. Distribution of Ratings per Genre

# %%
# Violin plot for rating distribution by genre
plt.figure(figsize=(14, 8))
sns.violinplot(data=df_exploded, x='genres', y='rating', palette='pastel')
plt.title('Distribution of Ratings by Genre')
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Model Building - Agglomerative Clustering

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules


# Input the userId
user_id = int(input("Enter the userId: "))

# Filter data for the selected user
user_data = merged_data[merged_data['userId'] == user_id]

# Select 5 random movies from the user's data
random_movies = user_data.sample(n=5)

# Extract genres from the selected random movies (assuming genres are pipe-separated)
random_movies['genre_list'] = random_movies['genres'].str.split('|')

# Print the selected random movies and their genres
#print("Random")
#print(random_movies[['movieId', 'title', 'genres', 'genre_list']])

# Create a one-hot encoded dataframe for genres
genre_dummies = merged_data['genres'].str.get_dummies('|')

# Only include movies with rating > 3 (optional if needed)
high_rated_movies = merged_data[merged_data['rating'] > 3]

# One-hot encoding for genres of movies with rating > 3
genre_dummies_high_rated = high_rated_movies['genres'].str.get_dummies('|')

# Use apriori to find frequent itemsets with minimum support
frequent_itemsets = apriori(genre_dummies_high_rated, min_support=0.1, use_colnames=True)

# Generate association rules from the frequent itemsets
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Inspect the top rules based on lift
print(rules[['antecedents', 'consequents', 'lift']].head())

# Now, based on the genres of the 5 random movies, we can recommend similar movies
# Extract the genres from the random movies
random_genres = random_movies['genre_list'].explode().unique()

# Recommend movies that match the genres of the random movies
recommended_movies = high_rated_movies[high_rated_movies['genres'].str.contains('|'.join(random_genres))]

# Get distinct recommended movie titles (with rating > 3)
recommended_movie_titles = recommended_movies[['movieId','title']].drop_duplicates()

# Print the recommended movie titles
print("Recommended Movies:")
print(recommended_movie_titles)
# Out:
# Enter the userId: 5249
# /Users/azharmadanisyed/anaconda3/lib/python3.11/site-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#    antecedents  consequents      lift
# 0     (Action)  (Adventure)  2.051337
# 1  (Adventure)     (Action)  2.051337
# 2     (Action)   (Thriller)  1.711771
# 3   (Thriller)     (Action)  1.711771
# 4    (Romance)     (Comedy)  1.575590
# Recommended Movies:
#           movieId                                              title
# 0               1                                   Toy Story (1995)
# 49695           2                                     Jumanji (1995)
# 71938           3                            Grumpier Old Men (1995)
# 84681           4                           Waiting to Exhale (1995)
# ...

# %%
# Get the list of movies the user has already watched
watched_movies = user_data[['movieId', 'title']]

# Print the list of movies that the user has already watched
print("\nMovies Already Watched by User:")
print(watched_movies)

# Now, we filter out the movies that the user has already watched from the recommended movies
# This will give us movies that the user has not yet watched
new_recommended_movies = recommended_movie_titles[~recommended_movie_titles['movieId'].isin(watched_movies['movieId'])]

# Print the new recommended movies (not watched by the user)
print("\nNew Recommended Movies (Not Watched by User):")
print(new_recommended_movies)
# Out:
# Movies Already Watched by User:
#           movieId                                              title
# 247345         19              Ace Ventura: When Nature Calls (1995)
# 1775397       266                         Legends of the Fall (1994)
# 2409928       350                                 Client, The (1994)
# 2648137       368                                    Maverick (1994)
# 3006693       442                              Demolition Man (1993)
# 3384475       508                                Philadelphia (1993)
# 3403869       509                                  Piano, The (1993)
# 4076554       594             Snow White and the Seven Dwarfs (1937)
# 4412326       708                Truth About Cats & Dogs, The (1996)
# 4574536       750  Dr. Strangelove or: How I Learned to Stop Worr...
# 4733160       786                                      Eraser (1996)
# 6375051      1208                              Apocalypse Now (1979)
# ...

# %%
lst = merged_data.title.unique()[:20]
lst
# Out:
# array(['Toy Story (1995)', 'Jumanji (1995)', 'Grumpier Old Men (1995)',
#        'Waiting to Exhale (1995)', 'Father of the Bride Part II (1995)',
#        'Heat (1995)', 'Sabrina (1995)', 'Tom and Huck (1995)',
#        'Sudden Death (1995)', 'GoldenEye (1995)',
#        'American President, The (1995)',
#        'Dracula: Dead and Loving It (1995)', 'Balto (1995)',
#        'Nixon (1995)', 'Cutthroat Island (1995)', 'Casino (1995)',
#        'Sense and Sensibility (1995)', 'Four Rooms (1995)',
#        'Ace Ventura: When Nature Calls (1995)', 'Money Train (1995)'],
#       dtype=object)

# %%
sample_df = df[df['title'].isin(lst)]

# %%
sample_df
# Out:
#         movieId               title  \
# 0             1    Toy Story (1995)
# 1             1    Toy Story (1995)
# 2             1    Toy Story (1995)
# 3             1    Toy Story (1995)
# 4             1    Toy Story (1995)
# ...         ...                 ...
# 271511       20  Money Train (1995)
# 271512       20  Money Train (1995)
# 271513       20  Money Train (1995)
# 271514       20  Money Train (1995)
# 271515       20  Money Train (1995)
#
#                                              genres  userId  rating
# 0       Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2       Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# 4       Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# ...                                             ...     ...     ...
# ...

# %%
sample_df.dtypes
# Out:
# movieId      int64
# title       object
# genres      object
# userId       int64
# rating     float64
# dtype: object

# %%
sample_df.to_csv('/Users/azharmadanisyed/Desktop/archive/sample_data.csv', index = False)
